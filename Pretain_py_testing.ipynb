# %% [markdown]
# <a href="https://colab.research.google.com/github/Janhvesh-Patil/Net-Neutral-AI/blob/main/Pretain_py_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Janhvesh-Patil/Net-Neutral-AI /content/net-neutral-ai
# %cd /content/net-neutral-ai
# Out:
# Cloning into '/content/net-neutral-ai'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 75 (delta 29), reused 54 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 25.33 MiB | 21.50 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/net-neutral-ai

# %%
# !pip install torch datasets -q

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !ls data
# Out:
# imdb_test.csv  imdb_train.csv  vocab.json

# %%
# !python coordinator/pretrain.py data
# Out:
# ════════════════════════════════════════════════════════════
#   Net-Neutral AI   |   PRETRAIN
#   Baseline checkpoint generation
# ════════════════════════════════════════════════════════════
#
#   ✓  GPU detected: Tesla T4
#
#   Device                      CUDA
#   Epochs                      5
#   Learning rate               0.001
#   Batch size                  32
#   Training samples            15,000
#   Checkpoint path             /content/net-neutral-ai/coordinator/checkpoint.pt
#
# ────────────────────────────────────────────────────────────
#   Loading data...
# ────────────────────────────────────────────────────────────
# [data.py] Loading from local CSV files...
# [data.py] Loaded 40,000 train + 10,000 test samples
# [Vocabulary] Loaded from data/vocab.json — size: 10,000
# [data.py] Validation set: 2,000 samples
#   Train batches               469
#   Val samples                 2,000
#
# ────────────────────────────────────────────────────────────
# ...

# %%
# In Colab — download the files
from google.colab import files
files.download('/content/net-neutral-ai/coordinator/checkpoint.pt')
files.download('/content/net-neutral-ai/coordinator/pretrain_log.json')
